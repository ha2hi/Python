# %% [markdown]
# 딕셔너리(Dictionary)
# - 키 값은 유일해야한다.

# %%
score = {
    'math' : 97,
    'eng' : 49,
    'kor' : 89
}
print(score['math'])
# Out:
# 97

# %%
score['math'] = 45
print(score['math'])
# Out:
# 45

# %%
score['sci'] = 100
print(score)
# Out:
# {'math': 45, 'eng': 49, 'kor': 89, 'sci': 100}

# %%
print('music' in score)
# Out:
# False

# %%
if 'music' in score:
    print(score['music'])
else:
    score['music'] = 0
# hash table에서 in연산은 random access처럼 사용되기 때문에 시간 복잡도는 O(1)이된다.
# Out:
# <function dict.values>

# %%
"""
정수가 저장된 배열 nums이 주어졌을때, nums의 원소중 두 숫자를 더해서 
target 값이 나오면 True, 아니면 False를 Return하세요
input : nums = {4,1,9,7,5,3,16}, taget : 14
output : True
"""
def TwoSum(nums, target):
    dict = {}
    for x in nums:
        dict[x] = True
    for x
