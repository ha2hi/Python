# %% [markdown]
# Apache Spark에 필요한 환경 & 패키지
# 1. 아나콘다
# 2. 자바
# 3. scala
# 4. apache-spark
# 5. pyspark

# %% [markdown]
# 데이터 셋
# TLC Trip Record Data
# 10+년 이상의 택시와 모빌리티 서비스 기록
# 2009년부터 2021년까지 모든 기록이 공개
#
# https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
# 2020년 3월데이터 다운로드
#
# [컬럼 정보]
# hvfhs_license_num : 회사 면허 번호
# dispatching_base_num : 지역 라이센스 번호
# pickup_datatime : 승차시간
# dropoff_datatime : 하차시간
# PULocationID : 승차 지역 ID
# DOLocationID : 하차 지역 ID
# SR_Flag : 탑승 여부 Flag

# %% [markdown]
# [소스 코드]
# github.com/keon/data-engineering <- git clone
